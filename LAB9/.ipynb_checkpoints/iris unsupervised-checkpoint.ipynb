# %% [markdown]
# # ML Lab 6: Unsupervised machine learning on Iris Dataset using PCA
#
# # Import data

# %%
import matplotlib.pyplot as plt
from sklearn import datasets
import sklearn.metrics as sm
import seaborn as sns 

import pandas as pd
import numpy as np
 
# Only needed if you want to display your plots inline if using Notebook
# change inline to auto if you have Spyder installed
# %matplotlib inline

# import some data to play with
iris = datasets.load_iris()

species_dict = dict(zip(range(0, len(iris.target_names)), iris.target_names))

iris_species = list((map(lambda x : species_dict[x], iris.target)))

iris.data[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
iris.target[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ## Put data into pandas dataframe

# %%
X = pd.DataFrame(iris.data, columns = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width'])
y = pd.DataFrame(iris.target, columns = ['Targets'])

# %% [markdown]
# ## Visualize data

# %%
# Set the size of the plot
plt.figure(figsize=(14,7))
 
# Plot Sepal
plt.subplot(1, 2, 1) # Creating subplots (1st subplot of 1 row, 2 columns)

# Produce a scatter plot for the sepal length and width 
plt.scatter(x.Sepal_Length, x.Sepal_Width)
plt.xlabel('Length')
plt.ylabel('Width')

plt.title('Sepal')
 
plt.subplot(1, 2, 2)
# Produce a scatter plot for the petal length and width 
plt.scatter(x.Petal_Length, x.Petal_Width)
plt.xlabel('Length')
plt.ylabel('Width')

plt.title('Petal')
# Out:
# Text(0.5, 1.0, 'Petal')

# %% [markdown]
# # Preprocessing
# ## Scale the data and reduce it to 2 dims using PCA

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)
# Perform the necessary imports
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Create scaler: scaler
scaler = StandardScaler()

# Create a PCA instance: pca
pca = PCA()

# Fit_transform scaler to 'X'
X_norm = scaler.fit_transform(x)

# Fit pca to 'X'
pca.fit(X_norm)

# Plot the explained variances
features = range(0, pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %% [markdown]
# **Feature 0 and 1 have the higest variance and can accurately represent 90%+ of the data. So we take only 2 components**
# ## Applying PCA

# %%
# Create a PCA model with 2 components: pca
pca = PCA(n_components=2)

# Fit the PCA instance to the scaled samples
pca.fit(X_norm)

# Transform the scaled samples: pca_features
pca_features = pca.transform(X_norm)

# Print the shape of pca_features
print(pca_features.shape)
# Out:
# (150, 2)

# %% [markdown]
# ### Visualize data after applying PCA

# %%
plt.scatter(pca_features[:, 0], pca_features[:, 1])

# %% [markdown]
# # Building models
# - ### Kmeans without PCA

# %%
# Import KMeans
from sklearn.cluster import KMeans

# Create a KMeans instance with 3 clusters: model
model = KMeans(n_clusters=3)

model.fit(X_norm)

labels = model.labels_

sns.scatterplot(pca_features[:, 0], pca_features[:, 1], hue=labels, palette=sns.color_palette("muted")[:3])
plt.show()

# %% [markdown]
# - ### Kmeans with PCA

# %%
# Create a KMeans model with 3 clusters: model
model = KMeans(n_clusters=3)

# Use fit_predict to fit model and obtain cluster labels: labels
labels = model.fit_predict(pca_features)

# Create a DataFrame with labels and varieties as columns: df
df = pd.DataFrame({'labels': labels, 'species': iris_species})

# Create crosstab: ct
ct = pd.crosstab(df['labels'], df['species'])

# Display ct
print(ct)
# Out:
# species  setosa  versicolor  virginica
# labels
# 0            50           0          0
# 1             0          39         16
# 2             0          11         34

# %%
sns.scatterplot(pca_features[:, 0], pca_features[:, 1], hue=labels, palette=sns.color_palette("muted")[:3])
plt.show()

# %% [markdown]
# ### Dendogram of Kmeans heirarchy

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Iris Dendograms")
dend = shc.dendrogram(shc.linkage(X_norm, method='ward'))

# %% [markdown]
# - ### Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering
# Out of the 4 linkage: single, complete, ward and average. Ward performs the best
model = AgglomerativeClustering(n_clusters=3, linkage='ward')
model.fit(pca_features)
labels = model.labels_

sns.scatterplot(pca_features[:, 0], pca_features[:, 1], hue=labels, palette=sns.color_palette("muted")[:3])
plt.show()

# %% [markdown]
# - ### Spectral Clustering

# %%
from sklearn.cluster import SpectralClustering
model = SpectralClustering(n_clusters=3)
model.fit(pca_features)
labels = model.labels_

sns.scatterplot(pca_features[:, 0], pca_features[:, 1], hue=labels, palette=sns.color_palette("muted")[:3])
plt.show()

# %% [markdown]
# # Actual Labels

# %%
sns.scatterplot(pca_features[:, 0], 
                pca_features[:, 1], hue=y.values.reshape(-1),  palette=sns.color_palette("muted")[:3])
plt.show()
